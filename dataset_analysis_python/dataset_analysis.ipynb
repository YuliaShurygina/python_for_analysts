# %% [markdown]
# ## Задача 1

# %% [markdown]
# - Скачать данные по ссылке https://www.kaggle.com/datasets/esratmaria/house-price-dataset-with-other-information
# - Описание датасета
# - Считать данные с помощью pandas
# - Вывести на экран первые 5 строк
# - Посмотреть на описание признаков и на их содержание

# %% [markdown]
# ### Описание датасета
# Данный датасет - это набор данных для прогнозирования цен на жилье с большой точностью.
#
# ### Содержание
# Датасет содержит 21 столбец, которые помогают определить цену дома и то, как эти компоненты влияют на цену дома.

# %%
import pandas as pd
data = pd.read_csv('kc_house_data.csv')
data.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %% [markdown]
# ### Признаки - 21:
# id(первичный ключ), дата, цена, количество спален, количество ванных комнат, жилая площадь кв.фут, общая площадь кв.фут, количество этажей, наличие набережной, наличие вида, состояние, оценка, площадь чердака кв.фут, площадь подвала кв.фут, год постройки, год последнего ремонта, почтовый индекс, широта, долгота, sqft_living15, sqft_lot15.

# %% [markdown]
# ## Задача 2

# %% [markdown]
# ### Проведите первичный анализ данных

# %% [markdown]
# - Изучите типы данных
# - Найдите количество пропущенных ячеек в данных
# - Посчитайте основные статистики по всем признакам и поизучайте их
# - Пишите выводы

# %%
data.dtypes
# Out:
# id                 int64
# date              object
# price            float64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %% [markdown]
# Все столбцы датасета состоят из числовых типов данных(int64, float64), за исключением столбца дата(тип данных object).

# %%
data.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %% [markdown]
# Таблица не содержит пустых ячеек.

# %%
data.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %% [markdown]
# Выше приведена статистика по признакам, тип данных которых числовой(int64, float64). Статистика по id, думаю, нам не пригодится.

# %%
cols = set(data.columns) - {'id'}
data1 = data[list(cols)]
data1.describe()
# Out:
#          sqft_above          view  sqft_living15          long      bedrooms  \
# count  21613.000000  21613.000000   21613.000000  21613.000000  21613.000000
# mean    1788.390691      0.234303    1986.552492   -122.213896      3.370842
# std      828.090978      0.766318     685.391304      0.140828      0.930062
# min      290.000000      0.000000     399.000000   -122.519000      0.000000
# 25%     1190.000000      0.000000    1490.000000   -122.328000      3.000000
# 50%     1560.000000      0.000000    1840.000000   -122.230000      3.000000
# 75%     2210.000000      0.000000    2360.000000   -122.125000      4.000000
# max     9410.000000      4.000000    6210.000000   -121.315000     33.000000
#
#            yr_built        floors  yr_renovated     bathrooms         price  \
# count  21613.000000  21613.000000  21613.000000  21613.000000  2.161300e+04
# mean    1971.005136      1.494309     84.402258      2.114757  5.400881e+05
# ...

# %% [markdown]
# Cтатистика по признакам, тип данных которых числовой(int64, float64), но без столбца id.

# %%
data.describe(include=['O'])
# Out:
#                    date
# count             21613
# unique              372
# top     20140623T000000
# freq                142

# %% [markdown]
# Выше приведена статистика по единственному признаку "date", тип данных которого object.

# %%
data.describe(include='all')
# Out:
#                   id             date         price      bedrooms  \
# count   2.161300e+04            21613  2.161300e+04  21613.000000
# unique           NaN              372           NaN           NaN
# top              NaN  20140623T000000           NaN           NaN
# freq             NaN              142           NaN           NaN
# mean    4.580302e+09              NaN  5.400881e+05      3.370842
# std     2.876566e+09              NaN  3.671272e+05      0.930062
# min     1.000102e+06              NaN  7.500000e+04      0.000000
# 25%     2.123049e+09              NaN  3.219500e+05      3.000000
# 50%     3.904930e+09              NaN  4.500000e+05      3.000000
# 75%     7.308900e+09              NaN  6.450000e+05      4.000000
# max     9.900000e+09              NaN  7.700000e+06     33.000000
#
#            bathrooms   sqft_living      sqft_lot        floors    waterfront  \
# count   21613.000000  21613.000000  2.161300e+04  21613.000000  21613.000000
# ...

# %% [markdown]
# Выше приведена статистика по всем типам данным.

# %% [markdown]
# ## Задача 3

# %% [markdown]
# ## 3.1 В каком диапазоне изменяются стоимости недвижимости?

# %%
[data['price'].min(), data['price'].max()]
# Out:
# [75000.0, 7700000.0]

# %% [markdown]
# ## 3.2 Какую долю в среднем занимают жилая площадь от всей площади по всем домам?

# %%
data['sqft_living'] #столбец с жилой площадью
# Out:
# 0        1180
# 1        2570
# 2         770
# 3        1960
# 4        1680
#          ...
# 21608    1530
# 21609    2310
# 21610    1020
# 21611    1600
# 21612    1020
# Name: sqft_living, Length: 21613, dtype: int64

# %%
data['sqft_lot'] #столбец с общей площадью
# Out:
# 0         5650
# 1         7242
# 2        10000
# 3         5000
# 4         8080
#          ...
# 21608     1131
# 21609     5813
# 21610     1350
# 21611     2388
# 21612     1076
# Name: sqft_lot, Length: 21613, dtype: int64

# %%
data1 = data['sqft_living']/data['sqft_lot'] #делим столбец с жилой площадью на столбец с общей
data1
# Out:
# 0        0.208850
# 1        0.354874
# 2        0.077000
# 3        0.392000
# 4        0.207921
#            ...
# 21608    1.352785
# 21609    0.397385
# 21610    0.755556
# 21611    0.670017
# 21612    0.947955
# Length: 21613, dtype: float64

# %%
data1.mean() # берем среднее от доли жилой площади
# Out:
# 0.32374472542047195

# %% [markdown]
# ## 3.3 Как много домов с разными этажами в данных?

# %%
data['floors'].value_counts()
# Out:
# 1.0    10680
# 2.0     8241
# 1.5     1910
# 3.0      613
# 2.5      161
# 3.5        8
# Name: floors, dtype: int64

# %% [markdown]
# ## 3.4 Насколько хорошее состояния у домов в данных?

# %%
data['condition'].mode()
# Out:
# 0    3
# dtype: int64

# %% [markdown]
# Самое частотное состояние на 3. Проверим через уникальные значения и частоту их появления

# %%
data['condition'].value_counts()
# Out:
# 3    14031
# 4     5679
# 5     1701
# 2      172
# 1       30
# Name: condition, dtype: int64

# %% [markdown]
# ## 3.5 Найдите года, когда построили первый дом, когда построили последний дом в данных?

# %%
data['yr_built'].min() # год, когда построили первый дом
# Out:
# 1900

# %%
data['yr_built'].max() # год, когда построили последний дом
# Out:
# 2015

# %% [markdown]
# ## 4.1 Сколько в среднем стоят дома, у которых 2 спальни?

# %%
data[data['bedrooms'] == 2]['price'].mean()
# Out:
# 401372.681884058

# %%
df = data[data['bedrooms'] == 2] #То же самое, но по-другому записано для лучшего понимания
df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 11     9212900260  20140527T000000  468000.0         2       1.00
# 18       16000397  20141205T000000  189000.0         2       1.00
# 23     8091400200  20140516T000000  252700.0         2       1.50
# 31     2426039314  20141201T000000  280000.0         2       1.50
# ...           ...              ...       ...       ...        ...
# 21586  2767604724  20141015T000000  505000.0         2       2.50
# 21588  2767600688  20141113T000000  414500.0         2       1.50
# 21595  1972201967  20141031T000000  520000.0         2       2.25
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 2              770     10000     1.0           0     0  ...      6
# ...

# %%
df['price'].mean()
# Out:
# 401372.681884058

# %% [markdown]
# ## 4.2 Какая в среднем общая площадь домов, у которых стоимость больше 600 000?

# %%
data[data['price'] > 600000]['sqft_lot'].mean()
# Out:
# 20442.524776214832

# %% [markdown]
# ## 4.3 Как много домов коснулся ремонт?

# %%
data[data['yr_renovated'] > 0]
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 1      6414100192  20141209T000000   538000.0         3       2.25
# 35     9547205180  20140613T000000   696000.0         3       2.50
# 95     1483300570  20140908T000000   905000.0         4       2.50
# 103    2450000295  20141007T000000  1088000.0         3       2.50
# 115    3626039325  20141121T000000   740500.0         3       3.50
# ...           ...              ...        ...       ...        ...
# 19622  7351200295  20150114T000000  1150000.0         3       1.75
# 20057   126039256  20140904T000000   434900.0         3       2.00
# 20444  4305600360  20150225T000000   500012.0         4       2.50
# 20447  3319500628  20150212T000000   356999.0         3       1.50
# 20962  1278000210  20150311T000000   110000.0         2       1.00
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 1             2570      7242     2.0           0     0  ...      7
# ...

# %%
data[data['yr_renovated'] > 0].shape ## ремонт коснулся 914 домов
# Out:
# (914, 21)

# %% [markdown]
# ## 4.4  Насколько в среднем стоимость домов с оценкой grade выше 10 отличается от стоимости домов с оценкой grade меньше 4?

# %%
a = data[data['grade'] > 10]['price'].mean()
a
# Out:
# 1678635.1175298805

# %%
b = data[data['grade'] < 4]['price'].mean()
b
# Out:
# 189750.0

# %%
a-b
# Out:
# 1488885.1175298805

# %% [markdown]
# Стоимость с оценкой больше 10 в среднем выше на 1 млн 489 тысяч

# %% [markdown]
# ## 5.1 Выберите дом клиенту
# ### Клиент хочет дом с видом на набережную, как минимум с тремя ванными и с подвалом. Сколько вариантов есть у клиента?

# %%
data[(data['waterfront'] > 0) & (data['sqft_basement'] > 0) & (data['bathrooms'] > 3)]
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 300    3225069065  20140624T000000  3075000.0         4       5.00
# 1164   1247600105  20141020T000000  5110800.0         5       5.25
# 1261   7636800041  20140625T000000   995000.0         3       4.50
# 1315   7558700030  20150413T000000  5300000.0         6       6.00
# 1361   1925069082  20150511T000000  2200000.0         5       4.25
# 2626   7738500731  20140815T000000  4500000.0         5       5.50
# 2864   4114601570  20141118T000000  3600000.0         3       3.25
# 3914   9808700762  20140611T000000  7062500.0         5       4.50
# 3934   1269200229  20140723T000000  1379900.0         3       3.25
# 5760    623059016  20140717T000000  1100000.0         4       3.25
# 6233   2024069008  20140619T000000  2200000.0         5       4.75
# 6508   4217402115  20150421T000000  3650000.0         6       4.75
# 7989   9362000040  20140623T000000  3400000.0         3       4.50
# ...

# %%
data[(data['waterfront'] > 0) & (data['sqft_basement'] > 0) & (data['bathrooms'] > 3)].shape
# Out:
# (36, 21)

# %% [markdown]
# 36 вариантов

# %% [markdown]
# ### Клиент хочет дом либо с очень красивым видом из окна, либо с видом на набережную, в очень хорошем состоянии и год постройки не меньше 1980 года. В какой ценовом диапазоне будут дома?

# %%
df = data[((data['view'] > 0) | (data['waterfront'] > 0)) & (data['yr_built'] >= 1980) & (data['condition'] == 5)]
df
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 858     623069068  20140627T000000   425000.0         3       1.00
# 3821   5452301810  20140905T000000  1575000.0         5       3.75
# 6045   4045100190  20141027T000000  2196000.0         4       3.25
# 8136   2597450620  20141009T000000  1511250.0         3       2.50
# 8791   5067400032  20141205T000000   550000.0         3       2.50
# 11257  3761100045  20140618T000000  3000000.0         4       4.25
# 12273  3220079017  20150213T000000   432000.0         5       2.75
# 14682  7278100515  20140821T000000  1295000.0         2       2.50
# 15997  2320069260  20141027T000000   415000.0         3       2.00
# 16120  2574900080  20140513T000000  1550000.0         5       3.25
# 17312  3585901025  20140613T000000  1735000.0         3       2.50
# 18991  7856400300  20140702T000000  1411600.0         2       2.50
# 18992  7856400300  20150322T000000  1505000.0         2       2.50
#
# ...

# %%
[df['price'].min(), df['price'].max()]
# Out:
# [415000.0, 3000000.0]

# %% [markdown]
# Ценовой диапазон от 415 тысяч до 3 млн.

# %% [markdown]
# ### Клиент хочет дом без подвала, с двумя этажами, стоимостью до 150000. Какая оценка по состоянию у таких домов в среднем?

# %%
df = data[(data['sqft_basement'] == 0) & (data['floors'] == 2) & (data['price'] < 150000)]
df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 2589   5061300030  20140508T000000  134000.0         2       1.50
# 10105  5466310060  20150324T000000  139500.0         2       1.50
# 15610  7614100080  20150211T000000  140000.0         3       1.75
# 18332  9272202260  20140924T000000  130000.0         3       1.00
# 18939  4239400300  20141129T000000   90000.0         3       1.00
# 18988  7399100210  20141126T000000  140000.0         3       1.50
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 2589           980      5000     2.0           0     0  ...      7
# 10105         1230      1561     2.0           0     0  ...      7
# 15610         1270      8991     2.0           0     0  ...      7
# 18332         1200      7000     2.0           0     0  ...      7
# 18939          980      2490     2.0           0     0  ...      6
# 18988         1200      2002     2.0           0     0  ...      8
#
# ...

# %%
df['condition'].mean()
# Out:
# 2.8333333333333335

# %% [markdown]
# Средняя оценка по состоянию 2.83
